# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


df = pd.read_csv("Virat-Kohli-International-Cricket-Centuries.csv")


df = df[["Runs", "Against", "Ground", "Position", "Innings", "Result"]].copy()

df["Runs"] = df["Runs"].astype(str)
df["Runs"] = df["Runs"].str.replace("*", "", regex=False)
df["Runs"] = df["Runs"].astype(int)


df["Against"] = df["Against"].str.strip()
df["Ground"] = df["Ground"].str.strip()
df["Result"] = df["Result"].str.strip()


le_against = LabelEncoder()
le_ground = LabelEncoder()
le_result = LabelEncoder()

df["Against"] = le_against.fit_transform(df["Against"])
df["Ground"] = le_ground.fit_transform(df["Ground"])
df["Result"] = le_result.fit_transform(df["Result"])


X = df[["Runs", "Against", "Ground", "Position", "Innings"]]
y = df["Result"]


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

split(
    X_scaled, y, test_size=0.25, random_state=42
)


model = LogisticRegression(max_iter=1000, class_weight="balanced")
model.fit(X_train, y_train)


y_pred = model.predict(X_test)


print("\nAccuracy:", accuracy_score(y_test, y_pred))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred, zero_division=0))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred))

# ----------------------------------------
# Custom Prediction (WARNING-FREE)
# ----------------------------------------
sample_df = pd.DataFrame([{
    "Runs": 120,
    "Against": le_against.transform(["Australia"])[0],
    "Ground": le_ground.transform(["Home"])[0],
    "Position": 4,
    "Innings": 2
}])

sample_scaled = scaler.transform(sample_df)
prediction = model.predict(sample_scaled)

print("\nPredicted Match Result:",
      le_result.inverse_transform(prediction)[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 39
#      36 scaler = StandardScaler()
#      37 X_scaled = scaler.fit_transform(X)
# ---> 39 split(
#      40     X_scaled, y, test_size=0.25, random_state=42
#      41 )
#      44 model = LogisticRegression(max_iter=1000, class_weight="balanced")
#      45 model.fit(X_train, y_train)
#
# NameError: name 'split' is not defined

# %%
import time
st=time.time()
# Python list (loop-based)
list1=[1,2,3,4,]
list_squares = [x ** 2 for x in list1]

en=time.time()
print(en-st)
# Out:
# 0.0005118846893310547
