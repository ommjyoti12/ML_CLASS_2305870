# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("data.csv")

# %%
data.head()
# Out:
#      NAME section  marks  Unnamed: 3 GRADE
# 0   agniv       A     87         NaN    E+
# 1   akash       B     45         NaN    A+
# 2  snehil       C     87         NaN    E+
# 3  aditya       A     87         NaN    E+
# 4  akash2       C     87         NaN    E+
