# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\kiit0001\anaconda3\anaaaa\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\kiit0001\anaconda3\anaaaa\lib\site-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kiit0001\anaconda3\anaaaa\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit0001\anaconda3\anaaaa\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kiit0001\anaconda3\anaaaa\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiit0001\anaconda3\anaaaa\lib\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kiit0001\anaconda3\anaaaa\lib\site-packages (from beautifulsoup4) (2.5)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = " cccccc"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
titles = []
prices = []
books = soup.find_all("article", class_="product_pod")

# %%
for book in books:
    title = book.h3.a["title"]
    price = book.find("p", class_="price_color").text

    titles.append(title)
    prices.append(price)

df = pd.DataFrame({
    "Title": titles,
    "Price": prices
})

df.to_csv("scraped_books.csv", index=False)
